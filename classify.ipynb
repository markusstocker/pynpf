# %%
from smear.datafetcher import fetchdata
from smear.dataplotter import plotdata
from factory import assess

# day = '2016-03-19'
day = '2016-01-07'
location = 'Hyytiälä'

data = fetchdata(day, location)

plotdata(data)
assess(data)
# Out:
# ['Non Event']
